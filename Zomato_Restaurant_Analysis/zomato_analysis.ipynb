# %%
print("Hello Zomato Project")
# Out:
# Hello Zomato Project

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/zomato.csv")

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.tail()
# Out:
#                                                      url  \
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# ...

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  str
#  1   address                      51717 non-null  str
#  2   name                         51717 non-null  str
#  3   online_order                 51717 non-null  str
#  4   book_table                   51717 non-null  str
#  5   rate                         43942 non-null  str
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  str
#  8   location                     51696 non-null  str
#  9   rest_type                    51490 non-null  str
#  10  dish_liked                   23639 non-null  str
#  11  cuisines                     51672 non-null  str
#  12  approx_cost(for two people)  51371 non-null  str
# ...

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df["rate"]
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51712    3.6 /5
# 51713       NaN
# 51714       NaN
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 51717, dtype: str

# %%
df["rate"].head(10)
# Out:
# 0    4.1/5
# 1    4.1/5
# 2    3.8/5
# 3    3.7/5
# 4    3.8/5
# 5    3.8/5
# 6    3.6/5
# 7    4.6/5
# 8    4.0/5
# 9    4.2/5
# Name: rate, dtype: str

# %%
df["rate"].unique()
# Out:
# <StringArray>
# [ '4.1/5',  '3.8/5',  '3.7/5',  '3.6/5',  '4.6/5',  '4.0/5',  '4.2/5',
#   '3.9/5',  '3.1/5',  '3.0/5',  '3.2/5',  '3.3/5',  '2.8/5',  '4.4/5',
#   '4.3/5',    'NEW',  '2.9/5',  '3.5/5',      nan,  '2.6/5', '3.8 /5',
#   '3.4/5',  '4.5/5',  '2.5/5',  '2.7/5',  '4.7/5',  '2.4/5',  '2.2/5',
#   '2.3/5', '3.4 /5',      '-', '3.6 /5',  '4.8/5', '3.9 /5', '4.2 /5',
#  '4.0 /5', '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#  '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5', '4.3 /5',
#  '4.4 /5',  '4.9/5',  '2.1/5',  '2.0/5',  '1.8/5', '4.6 /5', '4.9 /5',
#  '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5', '2.2 /5',
#  '2.0 /5', '1.8 /5']
# Length: 65, dtype: str

# %%
df["rate"].value_counts()
# Out:
# rate
# NEW       2208
# 3.9/5     2098
# 3.8/5     2022
# 3.7/5     2011
# 3.9 /5    1874
#           ...
# 2.2 /5       7
# 2.0 /5       7
# 2.0/5        4
# 1.8 /5       3
# 1.8/5        2
# Name: count, Length: 64, dtype: int64

# %%
df["rate"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df_backup = df.copy()

# %%
df["rate"].iloc[0]
# Out:
# '4.1/5'

# %%
df["rate"].str.replace("/5","")
# Out:
# 0         4.1
# 1         4.1
# 2         3.8
# 3         3.7
# 4         3.8
#          ...
# 51712    3.6
# 51713     NaN
# 51714     NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: str

# %%
df["rate"] = df["rate"].str.replace("/5","")

# %%
df["rate"] == "NEW"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Name: rate, Length: 51717, dtype: bool

# %%
df[df["rate"] == "NEW"]
# Out:
#                                                      url  \
# 72     https://www.zomato.com/bangalore/spicy-tandoor...
# 75     https://www.zomato.com/bangalore/om-sri-vinaya...
# 110    https://www.zomato.com/bangalore/hari-super-sa...
# 130    https://www.zomato.com/bangalore/roll-magic-fa...
# 131    https://www.zomato.com/bangalore/foodlieious-m...
# ...                                                  ...
# 51585  https://www.zomato.com/bangalore/wow-tiffin-fo...
# 51586  https://www.zomato.com/bangalore/quick-bites-w...
# 51603  https://www.zomato.com/bangalore/shiv-sagar-1-...
# 51604  https://www.zomato.com/bangalore/nawab-di-biry...
# 51605  https://www.zomato.com/bangalore/bong-connecti...
#
#                                                  address  \
# 72     Opposite ICICi Bank, Hanuman Nagar, Banashanka...
# 75     39, S B M Colony, Near-Sita Circle, 1st Stage,...
# 110    594, 24 The Cross BSK, Opposte Oriental Bank, ...
# ...

# %%
df[df["rate"] == "-"]
# Out:
#                                                      url  \
# 3068   https://www.zomato.com/bangalore/house-of-tast...
# 3069   https://www.zomato.com/bangalore/super-chefs-b...
# 3373   https://www.zomato.com/bangalore/right-pizza-b...
# 3378   https://www.zomato.com/bangalore/mezban-family...
# 3387   https://www.zomato.com/bangalore/mota-bawarchi...
# ...                                                  ...
# 33454  https://www.zomato.com/bangalore/deepam-tiffin...
# 33463  https://www.zomato.com/bangalore/hotel-orchid-...
# 45646  https://www.zomato.com/bangalore/sri-udupi-air...
# 45647  https://www.zomato.com/bangalore/frozen-bite-a...
# 48139  https://www.zomato.com/bangalore/dads-coffee-c...
#
#                                                  address  \
# 3068         #235/1 12th Cross, Wilson Garden, Bangalore
# 3069   8/3, Opposite Suryadhoya Convention hall, Bann...
# 3373   Shop 9, East Anjanaiya Temple Street, Gandhi B...
# ...

# %%
(df["rate"] == "NEW").sum()
# Out:
# np.int64(2208)

# %%
(df["rate"] == "-").sum()
# Out:
# np.int64(69)

# %%
df["rate"] = df["rate"].replace("NEW", None)

# %%
df["rate"] = df["rate"].replace("-", None)

# %%
df["rate"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["rate"] = pd.to_numeric(df["rate"])

# %%
df["rate"].dtype
# Out:
# dtype('float64')

# %%
df["rate"].mean()
# Out:
# np.float64(3.700448817952718)

# %%
df["approx_cost(for two people)"].isnull().sum()
# Out:
# np.int64(346)

# %%
df["approx_cost(for two people)"].head(10)
# Out:
# 0    800.0
# 1    800.0
# 2    800.0
# 3    300.0
# 4    600.0
# 5    600.0
# 6    800.0
# 7    600.0
# 8    700.0
# 9    550.0
# Name: approx_cost(for two people), dtype: float64

# %%
df["approx_cost(for two people)"] = pd.to_numeric(
    df["approx_cost(for two people)"]
)

# %%
df["approx_cost(for two people)"].dtype
# Out:
# dtype('float64')

# %%
df["approx_cost(for two people)"].mean()
# Out:
# np.float64(555.4315664479959)

# %%
len(df[df["rate"] > 4.5])
# Out:
# 588

# %%
df[df["rate"] > 4.5][["name","rate"]]
# Out:
#                            name  rate
# 7                        Onesta   4.6
# 44                       Onesta   4.6
# 164    The Blue Wagon - Kitchen   4.6
# 557                      Onesta   4.6
# 632                Taaza Thindi   4.7
# ...                         ...   ...
# 51606                   Chianti   4.6
# 51649                Biergarten   4.7
# 51650      Windmills Craftworks   4.6
# 51685                Biergarten   4.7
# 51686      Windmills Craftworks   4.6
#
# [588 rows x 2 columns]

# %%
df[df["rate"] > 4.5][["name","rate"]].sort_values(
    by="rate",
    ascending=False
)
# Out:
#                                                     name  rate
# 29271                     Asia Kitchen By Mainland China   4.9
# 46960                                       Punjab Grill   4.9
# 29560                     Asia Kitchen By Mainland China   4.9
# 46253                                       Punjab Grill   4.9
# 45812  SantÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...   4.9
# ...                                                  ...   ...
# 28408                                  The Boozy Griffin   4.6
# 557                                               Onesta   4.6
# 51044                                     Oota Bangalore   4.6
# 51039                               Windmills Craftworks   4.6
# 50927                                            BelgYum   4.6
#
# [588 rows x 2 columns]

# %%
df[(df["rate"] > 4) & (df["approx_cost(for two people)"] < 500)]
# Out:
#                                                      url  \
# 51     https://www.zomato.com/bangalore/shree-cool-po...
# 52     https://www.zomato.com/bangalore/corner-house-...
# 65     https://www.zomato.com/bangalore/kabab-magic-b...
# 71     https://www.zomato.com/bangalore/the-biryani-c...
# 76     https://www.zomato.com/bangalore/sri-guru-kott...
# ...                                                  ...
# 51258  https://www.zomato.com/bangalore/masala-chai-1...
# 51311  https://www.zomato.com/bangalore/mooch-marod-w...
# 51312  https://www.zomato.com/bangalore/biryani-kitch...
# 51376  https://www.zomato.com/bangalore/nu-tree-1-whi...
# 51437  https://www.zomato.com/bangalore/captain-egg-w...
#
#                                                  address  \
# 51     1514, 4th Cross, 7th Main, RPC layout, 2nd Sta...
# 52     808/6-1, 24th A Cross, K.R Road, 2nd Stage, Ba...
# 65     31, Opposite Vijaya College, RV Road, Basavana...
# ...

# %%
df[
    (df["rate"] > 4) &
    (df["approx_cost(for two people)"] < 500)
][
    ["name",
     "rate",
     "approx_cost(for two people)",
     "location"]
]
# Out:
#                                               name  rate  \
# 51                                Shree Cool Point   4.1
# 52                          Corner House Ice Cream   4.3
# 65                                     Kabab Magic   4.1
# 71                                The Biryani Cafe   4.1
# 76     Sri Guru Kottureshwara Davangere Benne Dosa   4.1
# ...                                            ...   ...
# 51258                                  Masala Chai   4.1
# 51311                                  Mooch Marod   4.5
# 51312                              Biryani Kitchen   4.3
# 51376                                      nu.tree   4.2
# 51437                                  Captain Egg   4.1
#
#        approx_cost(for two people)      location
# 51                           150.0   Vijay Nagar
# 52                           400.0  Banashankari
# 65                           400.0  Basavanagudi
# 71                           300.0  Banashankari
# ...

# %%
len(
    df[
        (df["rate"] > 4) &
        (df["approx_cost(for two people)"] < 500)
    ]
)
# Out:
# 1869

# %% [markdown]
# Find the top 10 cheapest restaurants with ratings above 4.5.

# %%
df[(df["rate"] > 4.5)].sort_values(
    by="approx_cost(for two people)",
    ascending=True
).head(10)
# Out:
#                                                      url  \
# 632    https://www.zomato.com/bangalore/taaza-thindi-...
# 3338   https://www.zomato.com/bangalore/brahmins-coff...
# 39518  https://www.zomato.com/bangalore/ctr-malleshwa...
# 40161  https://www.zomato.com/bangalore/ctr-malleshwa...
# 46445  https://www.zomato.com/bangalore/ctr-malleshwa...
# 46973  https://www.zomato.com/bangalore/ctr-malleshwa...
# 18501  https://www.zomato.com/bangalore/natural-ice-c...
# 46630  https://www.zomato.com/bangalore/o-g-variar-so...
# 18031  https://www.zomato.com/bangalore/apsara-ice-cr...
# 18516  https://www.zomato.com/bangalore/apsara-ice-cr...
#
#                                                  address  \
# 632    115, 100 Feet Ring Road, Kathriguppe, Banashan...
# 3338   Ranga Rao Road, Near Shankar Mutt, Shankarapur...
# 39518   7th Cross, Margosa Road, Malleshwaram, Bangalore
# 40161   7th Cross, Margosa Road, Malleshwaram, Bangalore
# ...

# %%
df[df["rate"] > 4.5][["name","rate"]].sort_values(
    by="rate",
    ascending=False
)
# Out:
#                                                     name  rate
# 29271                     Asia Kitchen By Mainland China   4.9
# 46960                                       Punjab Grill   4.9
# 29560                     Asia Kitchen By Mainland China   4.9
# 46253                                       Punjab Grill   4.9
# 45812  SantÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...   4.9
# ...                                                  ...   ...
# 28408                                  The Boozy Griffin   4.6
# 557                                               Onesta   4.6
# 51044                                     Oota Bangalore   4.6
# 51039                               Windmills Craftworks   4.6
# 50927                                            BelgYum   4.6
#
# [588 rows x 2 columns]

# %%
df.groupby("location")["name"].count()
# Out:
# location
# BTM                  5124
# Banashankari          906
# Banaswadi             664
# Bannerghatta Road    1630
# Basavanagudi          684
#                      ...
# West Bangalore          6
# Whitefield           2144
# Wilson Garden         246
# Yelahanka               6
# Yeshwantpur           119
# Name: name, Length: 93, dtype: int64

# %%
df.groupby("location")["name"].count().sort_values( ascending=False)
# Out:
# location
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# West Bangalore              6
# Yelahanka                   6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: name, Length: 93, dtype: int64

# %%
df.groupby("location")["name"].count().sort_values( ascending=False).head(10)
# Out:
# location
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
# Indiranagar              2083
# Jayanagar                1926
# Marathahalli             1846
# Bannerghatta Road        1630
# Bellandur                1286
# Name: name, dtype: int64

# %%
df.groupby("location")["rate"].mean().sort_values(ascending=False).head(1)
# Out:
# location
# Lavelle Road    4.142505
# Name: rate, dtype: float64

# %%
df.groupby("location")["rate"].agg(["mean","sum","count","max","min"])
# Out:
#                        mean      sum  count  max  min
# location
# BTM                3.573740  14044.8   3930  4.9  2.4
# Banashankari       3.649866   2715.5    744  4.7  2.5
# Banaswadi          3.496042   1678.1    480  4.4  2.3
# Bannerghatta Road  3.507449   4331.7   1235  4.6  2.2
# Basavanagudi       3.671092   2184.3    595  4.8  2.5
# ...                     ...      ...    ...  ...  ...
# West Bangalore     3.366667     10.1      3  3.5  3.3
# Whitefield         3.621618   5729.4   1582  4.9  2.4
# Wilson Garden      3.536364    661.3    187  4.0  3.0
# Yelahanka          3.640000     18.2      5  3.9  3.4
# Yeshwantpur        3.502679    392.3    112  4.2  2.8
#
# [93 rows x 5 columns]

# %%
df.groupby("location")["rate"].agg(["mean","sum","count","max","min"]).round(2)
# Out:
#                    mean      sum  count  max  min
# location
# BTM                3.57  14044.8   3930  4.9  2.4
# Banashankari       3.65   2715.5    744  4.7  2.5
# Banaswadi          3.50   1678.1    480  4.4  2.3
# Bannerghatta Road  3.51   4331.7   1235  4.6  2.2
# Basavanagudi       3.67   2184.3    595  4.8  2.5
# ...                 ...      ...    ...  ...  ...
# West Bangalore     3.37     10.1      3  3.5  3.3
# Whitefield         3.62   5729.4   1582  4.9  2.4
# Wilson Garden      3.54    661.3    187  4.0  3.0
# Yelahanka          3.64     18.2      5  3.9  3.4
# Yeshwantpur        3.50    392.3    112  4.2  2.8
#
# [93 rows x 5 columns]

# %%
df["cuisines"].head(10)
# Out:
# 0                 North Indian, Mughlai, Chinese
# 1                    Chinese, North Indian, Thai
# 2                         Cafe, Mexican, Italian
# 3                     South Indian, North Indian
# 4                       North Indian, Rajasthani
# 5                                   North Indian
# 6    North Indian, South Indian, Andhra, Chinese
# 7                           Pizza, Cafe, Italian
# 8                     Cafe, Italian, Continental
# 9       Cafe, Mexican, Italian, Momos, Beverages
# Name: cuisines, dtype: str

# %%
df["online_order"].value_counts()
# Out:
# online_order
# Yes    30444
# No     21273
# Name: count, dtype: int64

# %%
df.groupby("online_order")["name"].count().sort_values(ascending=False)
# Out:
# online_order
# Yes    30444
# No     21273
# Name: name, dtype: int64

# %% [markdown]
# Find the top 5 locations with the highest number of restaurants.

# %%
df['book_table'].value_counts()
# Out:
# book_table
# No     45268
# Yes     6449
# Name: count, dtype: int64

# %%
df['book_table'].replace("Yes","1")
# Out:
# 0         1
# 1        No
# 2        No
# 3        No
# 4        No
#          ..
# 51712    No
# 51713    No
# 51714    No
# 51715     1
# 51716    No
# Name: book_table, Length: 51717, dtype: str

# %%
def order_status(value):

    if value == "Yes":
        return 1
    else:
        return 0

# %%
df["online_order"] = df["online_order"].apply(order_status)

# %%
df["online_order"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 51712    0
# 51713    0
# 51714    0
# 51715    0
# 51716    0
# Name: online_order, Length: 51717, dtype: int64

# %%
df = df_backup.copy()

# %%
df_backup2=df.copy()

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  str
#  1   address                      51717 non-null  str
#  2   name                         51717 non-null  str
#  3   online_order                 51717 non-null  str
#  4   book_table                   51717 non-null  str
#  5   rate                         41665 non-null  float64
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  str
#  8   location                     51696 non-null  str
#  9   rest_type                    51490 non-null  str
#  10  dish_liked                   23639 non-null  str
#  11  cuisines                     51672 non-null  str
#  12  approx_cost(for two people)  51371 non-null  float64
# ...

# %%
df["approx_cost(for two people)"].isnull().sum()
# Out:
# np.int64(346)

# %%
df["approx_cost(for two people)"].head(30)
# Out:
# 0     800.0
# 1     800.0
# 2     800.0
# 3     300.0
# 4     600.0
# 5     600.0
# 6     800.0
# 7     600.0
# 8     700.0
# 9     550.0
# 10    500.0
# 11    600.0
# 12    500.0
# 13    450.0
# 14    800.0
# 15    650.0
# 16    800.0
# 17    700.0
# 18    300.0
# 19    400.0
# 20    400.0
# 21    500.0
# 22    900.0
# 23    600.0
# 24    300.0
# 25    600.0
# 26    200.0
# 27    500.0
# 28    550.0
# 29    550.0
# Name: approx_cost(for two people), dtype: float64

# %%
df["book_table"]
# Out:
# 0        Yes
# 1         No
# 2         No
# 3         No
# 4         No
#         ...
# 51712     No
# 51713     No
# 51714     No
# 51715    Yes
# 51716     No
# Name: book_table, Length: 51717, dtype: str

# %%
df["book_table"] = df["book_table"].apply(
    lambda value: 1 if value == "Yes" else 0
)

# %%
df["book_table"]
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 51712    0
# 51713    0
# 51714    0
# 51715    1
# 51716    0
# Name: book_table, Length: 51717, dtype: int64

# %%
df["online_order"]
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3         No
# 4         No
#         ...
# 51712     No
# 51713     No
# 51714     No
# 51715     No
# 51716     No
# Name: online_order, Length: 51717, dtype: str

# %%
def order_status(value):

    if value=="Yes":
        return 1
    else:
        return 0

df["online_order"].apply(order_status)
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        0
#         ..
# 51712    0
# 51713    0
# 51714    0
# 51715    0
# 51716    0
# Name: online_order, Length: 51717, dtype: int64

# %%
df["rate"]
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51712    3.6
# 51713    NaN
# 51714    NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: float64

# %%
df["approx_cost(for two people)"].head(50)
# Out:
# 0     800.0
# 1     800.0
# 2     800.0
# 3     300.0
# 4     600.0
# 5     600.0
# 6     800.0
# 7     600.0
# 8     700.0
# 9     550.0
# 10    500.0
# 11    600.0
# 12    500.0
# 13    450.0
# 14    800.0
# 15    650.0
# 16    800.0
# 17    700.0
# 18    300.0
# 19    400.0
# 20    400.0
# 21    500.0
# 22    900.0
# 23    600.0
# 24    300.0
# 25    600.0
# 26    200.0
# 27    500.0
# 28    550.0
# 29    550.0
# 30    600.0
# 31    500.0
# 32    500.0
# 33    750.0
# 34    500.0
# 35    650.0
# 36    400.0
# 37    600.0
# 38    750.0
# 39    150.0
# 40    200.0
# 41    300.0
# 42    500.0
# 43    800.0
# 44    600.0
# 45    400.0
# 46    300.0
# 47    450.0
# 48    850.0
# 49    300.0
# Name: approx_cost(for two people), dtype: float64

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order  book_table  rate  votes                             phone  \
# 0          Yes           1   4.1    775    080 42297555\r\n+91 9743772233
# ...

# %%
status = {
    "Yes":"Available",
    "No":"Not Available"
}

# %%
status["Yes"]

status["No"]
# Out:
# 'Not Available'

# %%
df["online_order"].map(status)
# Out:
# 0            Available
# 1            Available
# 2            Available
# 3        Not Available
# 4        Not Available
#              ...
# 51712    Not Available
# 51713    Not Available
# 51714    Not Available
# 51715    Not Available
# 51716    Not Available
# Name: online_order, Length: 51717, dtype: str

# %%
df["online_order_status"] = df["online_order"].map(status)

# %%
df[
    [
        "online_order",
        "online_order_status"
    ]
].head()
# Out:
#   online_order online_order_status
# 0          Yes           Available
# 1          Yes           Available
# 2          Yes           Available
# 3           No       Not Available
# 4           No       Not Available

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order  book_table  rate  votes                             phone  \
# 0          Yes           1   4.1    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=51717, step=1)

# %%
df.iloc[0]
# Out:
# url                            https://www.zomato.com/bangalore/jalsa-banasha...
# address                        942, 21st Main Road, 2nd Stage, Banashankari, ...
# name                                                                       Jalsa
# online_order                                                                 Yes
# book_table                                                                     1
# rate                                                                         4.1
# votes                                                                        775
# phone                                             080 42297555\r\n+91 9743772233
# location                                                            Banashankari
# rest_type                                                          Casual Dining
# dish_liked                     Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# cuisines                                          North Indian, Mughlai, Chinese
# ...

# %%
df.iloc[0][["name","address"]]
# Out:
# name                                                   Jalsa
# address    942, 21st Main Road, 2nd Stage, Banashankari, ...
# Name: 0, dtype: object

# %%
df.iloc[0]["name"]
# Out:
# 'Jalsa'

# %%
df.iloc[
    0,
    [1,2]
]
# Out:
# address    942, 21st Main Road, 2nd Stage, Banashankari, ...
# name                                                   Jalsa
# Name: 0, dtype: str

# %%
df.iloc[0,[2]]
# Out:
# name    Jalsa
# Name: 0, dtype: str

# %%
df.sort_values(by="rate", ascending=False)
# Out:
#                                                      url  \
# 50059  https://www.zomato.com/bangalore/byg-brewski-b...
# 32110  https://www.zomato.com/bangalore/asia-kitchen-...
# 43055  https://www.zomato.com/bangalore/belgian-waffl...
# 8260   https://www.zomato.com/bangalore/abs-absolute-...
# 42381  https://www.zomato.com/bangalore/belgian-waffl...
# ...                                                  ...
# 51644  https://www.zomato.com/bangalore/punjabi-thadk...
# 51675  https://www.zomato.com/bangalore/topsy-turvey-...
# 51710  https://www.zomato.com/bangalore/topsy-turvey-...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
#
#                                                  address  \
# 50059         Behind MK Retail, Sarjapur Road, Bangalore
# 32110  136, Ground Floor, 1st Cross, 5th Block, Jyoti...
# 43055  65, Markham Road, Ashok Nagar, Brigade Road, B...
# ...

# %%
df.sort_values(
    by=["rate", "votes"],
    ascending=[False, False]
)
# Out:
#                                                      url  \
# 49170  https://www.zomato.com/bangalore/byg-brewski-b...
# 49627  https://www.zomato.com/bangalore/byg-brewski-b...
# 50059  https://www.zomato.com/bangalore/byg-brewski-b...
# 3921   https://www.zomato.com/bangalore/byg-brewski-b...
# 4801   https://www.zomato.com/bangalore/byg-brewski-b...
# ...                                                  ...
# 51644  https://www.zomato.com/bangalore/punjabi-thadk...
# 51675  https://www.zomato.com/bangalore/topsy-turvey-...
# 51710  https://www.zomato.com/bangalore/topsy-turvey-...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
#
#                                                  address  \
# 49170         Behind MK Retail, Sarjapur Road, Bangalore
# 49627         Behind MK Retail, Sarjapur Road, Bangalore
# 50059         Behind MK Retail, Sarjapur Road, Bangalore
# ...

# %%
df.sort_values(
    by=["rate","votes"],
    ascending=[False,False]
)[
    [
        "name",
        "rate",
        "votes",
        "location"
    ]
].head(10)
# Out:
#                               name  rate  votes       location
# 49170  Byg Brewski Brewing Company   4.9  16832  Sarjapur Road
# 49627  Byg Brewski Brewing Company   4.9  16832  Sarjapur Road
# 50059  Byg Brewski Brewing Company   4.9  16832  Sarjapur Road
# 3921   Byg Brewski Brewing Company   4.9  16345  Sarjapur Road
# 4801   Byg Brewski Brewing Company   4.9  16345  Sarjapur Road
# 4944   Byg Brewski Brewing Company   4.9  16345  Sarjapur Road
# 37099    AB's - Absolute Barbecues   4.9   6490            BTM
# 21279    AB's - Absolute Barbecues   4.9   6452            BTM
# 19393    AB's - Absolute Barbecues   4.9   6404            BTM
# 21770    AB's - Absolute Barbecues   4.9   6404            BTM

# %%
df.sort_values(
    by=["rate", "approx_cost(for two people)"],
    ascending=[False, True]
)
# Out:
#                                                      url  \
# 5153   https://www.zomato.com/bangalore/belgian-waffl...
# 5809   https://www.zomato.com/bangalore/belgian-waffl...
# 10284  https://www.zomato.com/bangalore/belgian-waffl...
# 11745  https://www.zomato.com/bangalore/belgian-waffl...
# 12380  https://www.zomato.com/bangalore/belgian-waffl...
# ...                                                  ...
# 50480  https://www.zomato.com/bangalore/tasty-box-whi...
# 50631  https://www.zomato.com/bangalore/mayas-kitchen...
# 50637  https://www.zomato.com/bangalore/mk-dabbawala-...
# 50764  https://www.zomato.com/bangalore/innate-whitef...
# 51233  https://www.zomato.com/bangalore/mayas-kitchen...
#
#                                                  address  \
# 5153   65, Markham Road, Ashok Nagar, Brigade Road, B...
# 5809   65, Markham Road, Ashok Nagar, Brigade Road, B...
# 10284  13 KHB Colony, 17th Main, M.I.G, Koramangala 5...
# ...

# %%
df.groupby("location")["rate"].mean()
# Out:
# location
# BTM                  3.573740
# Banashankari         3.649866
# Banaswadi            3.496042
# Bannerghatta Road    3.507449
# Basavanagudi         3.671092
#                        ...
# West Bangalore       3.366667
# Whitefield           3.621618
# Wilson Garden        3.536364
# Yelahanka            3.640000
# Yeshwantpur          3.502679
# Name: rate, Length: 93, dtype: float64

# %%
pd.pivot_table(
    df,
    values="rate",
    index="location",
    aggfunc="mean"
)
# Out:
#                        rate
# location
# BTM                3.573740
# Banashankari       3.649866
# Banaswadi          3.496042
# Bannerghatta Road  3.507449
# Basavanagudi       3.671092
# ...                     ...
# West Bangalore     3.366667
# Whitefield         3.621618
# Wilson Garden      3.536364
# Yelahanka          3.640000
# Yeshwantpur        3.502679
#
# [92 rows x 1 columns]

# %%
pd.pivot_table(
    df,
    values="rate",
    index="location",
    columns="online_order",
    aggfunc="mean"
)
# Out:
# online_order             No       Yes
# location
# BTM                3.508061  3.597438
# Banashankari       3.563736  3.699788
# Banaswadi          3.464481  3.515488
# Bannerghatta Road  3.393857  3.563285
# Basavanagudi       3.626776  3.690777
# ...                     ...       ...
# West Bangalore     3.500000  3.300000
# Whitefield         3.576823  3.650259
# Wilson Garden      3.360937  3.627642
# Yelahanka          3.400000  3.700000
# Yeshwantpur        3.438095  3.517582
#
# [92 rows x 2 columns]

# %%
import pandas as pd

restaurant = pd.DataFrame({
    "id":[101,102,103],
    "name":["KFC","Domino's","Pizza Hut"]
})

restaurant
# Out:
#     id       name
# 0  101        KFC
# 1  102   Domino's
# 2  103  Pizza Hut

# %%
rating = pd.DataFrame({
    "id":[101,102,103],
    "rating":[4.2,4.5,4.0]
})

rating
# Out:
#     id  rating
# 0  101     4.2
# 1  102     4.5
# 2  103     4.0

# %%
pd.merge(
    restaurant,
    rating,
    on="id"
)
# Out:
#     id       name  rating
# 0  101        KFC     4.2
# 1  102   Domino's     4.5
# 2  103  Pizza Hut     4.0

# %%
df[
    (df["rate"] > 4) &
    (df["approx_cost(for two people)"] < 500)
]
# Out:
#                                                      url  \
# 51     https://www.zomato.com/bangalore/shree-cool-po...
# 52     https://www.zomato.com/bangalore/corner-house-...
# 65     https://www.zomato.com/bangalore/kabab-magic-b...
# 71     https://www.zomato.com/bangalore/the-biryani-c...
# 76     https://www.zomato.com/bangalore/sri-guru-kott...
# ...                                                  ...
# 51258  https://www.zomato.com/bangalore/masala-chai-1...
# 51311  https://www.zomato.com/bangalore/mooch-marod-w...
# 51312  https://www.zomato.com/bangalore/biryani-kitch...
# 51376  https://www.zomato.com/bangalore/nu-tree-1-whi...
# 51437  https://www.zomato.com/bangalore/captain-egg-w...
#
#                                                  address  \
# 51     1514, 4th Cross, 7th Main, RPC layout, 2nd Sta...
# 52     808/6-1, 24th A Cross, K.R Road, 2nd Stage, Ba...
# 65     31, Opposite Vijaya College, RV Road, Basavana...
# ...

# %%
df.query("rate > 4")
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 7      https://www.zomato.com/bangalore/onesta-banash...
# 9      https://www.zomato.com/bangalore/smacznego-ban...
# 10     https://www.zomato.com/bangalore/caf%C3%A9-dow...
# ...                                                  ...
# 51697  https://www.zomato.com/bangalore/shizusan-shop...
# 51699  https://www.zomato.com/bangalore/harrys-bar-ca...
# 51700  https://www.zomato.com/bangalore/bar-bar-white...
# 51701  https://www.zomato.com/bangalore/the-beer-cafe...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 7      2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# ...

# %%
df[
    (df["rate"] > 4) &
    (df["votes"] > 500)
]
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 7      https://www.zomato.com/bangalore/onesta-banash...
# 9      https://www.zomato.com/bangalore/smacznego-ban...
# 37     https://www.zomato.com/bangalore/szechuan-drag...
# ...                                                  ...
# 51696  https://www.zomato.com/bangalore/the-irish-hou...
# 51697  https://www.zomato.com/bangalore/shizusan-shop...
# 51699  https://www.zomato.com/bangalore/harrys-bar-ca...
# 51700  https://www.zomato.com/bangalore/bar-bar-white...
# 51701  https://www.zomato.com/bangalore/the-beer-cafe...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 7      2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# ...

# %%
df.query(
    "`approx_cost(for two people)` < 500 and rate > 4 and votes > 100"
)
# Out:
#                                                      url  \
# 52     https://www.zomato.com/bangalore/corner-house-...
# 65     https://www.zomato.com/bangalore/kabab-magic-b...
# 71     https://www.zomato.com/bangalore/the-biryani-c...
# 76     https://www.zomato.com/bangalore/sri-guru-kott...
# 81     https://www.zomato.com/bangalore/frozen-bottle...
# ...                                                  ...
# 50936  https://www.zomato.com/bangalore/mad-over-donu...
# 51028  https://www.zomato.com/bangalore/happy-endings...
# 51258  https://www.zomato.com/bangalore/masala-chai-1...
# 51311  https://www.zomato.com/bangalore/mooch-marod-w...
# 51312  https://www.zomato.com/bangalore/biryani-kitch...
#
#                                                  address  \
# 52     808/6-1, 24th A Cross, K.R Road, 2nd Stage, Ba...
# 65     31, Opposite Vijaya College, RV Road, Basavana...
# 71     476, 2nd Floor, 9th Cross, Avalahalli BDA Park...
# ...

# %%
df["name"].str.upper().head()
# Out:
# 0                    JALSA
# 1           SPICE ELEPHANT
# 2          SAN CHURRO CAFE
# 3    ADDHURI UDUPI BHOJANA
# 4            GRAND VILLAGE
# Name: name, dtype: str

# %%
df["name"].str.lower().head()
# Out:
# 0                    jalsa
# 1           spice elephant
# 2          san churro cafe
# 3    addhuri udupi bhojana
# 4            grand village
# Name: name, dtype: str

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [url, address, name, online_order, book_table, rate, votes, phone, location, rest_type, dish_liked, cuisines, approx_cost(for two people), reviews_list, menu_item, listed_in(type), listed_in(city), online_order_status]
# Index: []

# %%
df = df.drop_duplicates()

# %%
data = {
    "Marks":[80,None,75,None,90]
}

temp = pd.DataFrame(data)


temp["Marks"] = temp["Marks"].fillna(temp["Marks"].mean()).round(2)

temp
# Out:
#    Marks
# 0  80.00
# 1  81.67
# 2  75.00
# 3  81.67
# 4  90.00

# %%
temp["Marks"] = temp["Marks"].fillna(
    temp["Marks"].median()
)

temp
# Out:
#    Marks
# 0  80.00
# 1  81.67
# 2  75.00
# 3  81.67
# 4  90.00

# %%
temp["Marks"] = temp["Marks"].fillna(
    temp["Marks"].mode()[0]
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  str
#  1   address                      51717 non-null  str
#  2   name                         51717 non-null  str
#  3   online_order                 51717 non-null  str
#  4   book_table                   51717 non-null  int64
#  5   rate                         41665 non-null  float64
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  str
#  8   location                     51696 non-null  str
#  9   rest_type                    51490 non-null  str
#  10  dish_liked                   23639 non-null  str
#  11  cuisines                     51672 non-null  str
#  12  approx_cost(for two people)  51371 non-null  float64
# ...

# %%
missing = (
    df.isnull().sum()
    / len(df)
) * 100

missing.sort_values(
    ascending=False
)
# Out:
# dish_liked                     54.291626
# rate                           19.436549
# phone                           2.335789
# approx_cost(for two people)     0.669026
# rest_type                       0.438927
# cuisines                        0.087012
# location                        0.040606
# url                             0.000000
# address                         0.000000
# book_table                      0.000000
# votes                           0.000000
# name                            0.000000
# online_order                    0.000000
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# online_order_status             0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# url                                str
# address                            str
# name                               str
# online_order                       str
# book_table                       int64
# rate                           float64
# votes                            int64
# phone                              str
# location                           str
# rest_type                          str
# dish_liked                         str
# cuisines                           str
# approx_cost(for two people)    float64
# reviews_list                       str
# menu_item                          str
# listed_in(type)                    str
# listed_in(city)                    str
# online_order_status                str
# dtype: object

# %%
df["online_order"].value_counts(dropna=False)
# Out:
# online_order
# Yes    30444
# No     21273
# Name: count, dtype: int64

# %%
df["book_table"].value_counts(dropna=False)
# Out:
# book_table
# 0    45268
# 1     6449
# Name: count, dtype: int64

# %%
df["book_table"] = df["book_table"].map({1: "Yes", 0: "No"})

# %%
df["book_table"].value_counts(dropna=False)
# Out:
# book_table
# No     45268
# Yes     6449
# Name: count, dtype: int64

# %%
df["location"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["location"] = df["location"].str.strip()

# %%
df = df.dropna(
    subset=["location"]
)

# %%
df["rest_type"].isnull().sum()
# Out:
# np.int64(227)

# %%
df = df.dropna(
    subset=["rest_type"]
)

# %%
df["cuisines"].isnull().sum()
# Out:
# np.int64(24)

# %%
df = df.dropna(
    subset=["cuisines"]
)

# %%
df["dish_liked"].isnull().sum()
# Out:
# np.int64(27897)

# %%
df["menu_item"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["reviews_list"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            9961
# votes                              0
# phone                           1175
# location                           0
# rest_type                          0
# dish_liked                     27897
# cuisines                           0
# approx_cost(for two people)      318
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# online_order_status                0
# dtype: int64

# %%
print("Total Restaurants :", len(df))
# Out:
# Total Restaurants : 51466

# %%
print("Unique Restaurants :", df["name"].nunique())
# Out:
# Unique Restaurants : 8755

# %%
print("Unique Locations :", df["location"].nunique())
# Out:
# Unique Locations : 93

# %%
print("Average Rating :", round(df["rate"].mean(),2))
# Out:
# Average Rating : 3.7

# %%
print("Average Cost :", round(df["approx_cost(for two people)"].mean(),2))
# Out:
# Average Cost : 556.04

# %% [markdown]
# ### Insights
#
# - The dataset contains 51466 restaurants.
# - Restaurants are spread across 93 locations.
# - The average customer rating is 3.7
# - The average cost for two people is ₹ 556.

# %%
top_locations = (
    df["location"]
    .value_counts()
    .head(10)
)

top_locations
# Out:
# location
# BTM                      5097
# HSR                      2511
# Koramangala 5th Block    2504
# JP Nagar                 2222
# Whitefield               2120
# Indiranagar              2076
# Jayanagar                1924
# Marathahalli             1825
# Bannerghatta Road        1624
# Bellandur                1271
# Name: count, dtype: int64

# %%
top_locations_percentage = (
    df["location"]
    .value_counts(normalize=True)
    .head(10) * 100
)

top_locations_percentage.round(2)
# Out:
# location
# BTM                      9.90
# HSR                      4.88
# Koramangala 5th Block    4.87
# JP Nagar                 4.32
# Whitefield               4.12
# Indiranagar              4.03
# Jayanagar                3.74
# Marathahalli             3.55
# Bannerghatta Road        3.16
# Bellandur                2.47
# Name: proportion, dtype: float64

# %%
location_rating = (
    df.groupby("location")["rate"]
    .mean()
    .sort_values(ascending=False)
)

location_rating.head(10)
# Out:
# location
# Lavelle Road             4.142505
# Koramangala 3rd Block    4.020419
# St. Marks Road           4.017201
# Koramangala 5th Block    4.005821
# Church Street            3.992125
# Sankey Road              3.965385
# Koramangala 4th Block    3.918668
# Cunningham Road          3.901053
# Residency Road           3.863636
# MG Road                  3.855857
# Name: rate, dtype: float64

# %%
location_cost = (
    df.groupby("location")["approx_cost(for two people)"]
    .mean()
    .sort_values(ascending=False)
)

location_cost.head(10)
# Out:
# location
# Sankey Road         2505.555556
# Race Course Road    1309.352518
# Lavelle Road        1307.934990
# MG Road             1155.704698
# Infantry Road       1062.251656
# Residency Road       966.320475
# St. Marks Road       883.673469
# Langford Town        883.333333
# Cunningham Road      864.969450
# Church Street        834.885764
# Name: approx_cost(for two people), dtype: float64

# %%
location_count = (
    df.groupby("location")
    .size()
    .sort_values(ascending=False)
)

location_count.head(10)
# Out:
# location
# BTM                      5097
# HSR                      2511
# Koramangala 5th Block    2504
# JP Nagar                 2222
# Whitefield               2120
# Indiranagar              2076
# Jayanagar                1924
# Marathahalli             1825
# Bannerghatta Road        1624
# Bellandur                1271
# dtype: int64

# %% [markdown]
# ## Location Analysis Insights
#
# - BTM has the highest number of restaurants.
# - Some locations have significantly fewer restaurants.
# - Certain premium locations have higher average costs.
# - Ratings vary across different locations.

# %%
top_rest_type = (
    df["rest_type"]
    .value_counts()
    .head(10)
)

top_rest_type
# Out:
# rest_type
# Quick Bites           19129
# Casual Dining         10326
# Cafe                   3732
# Delivery               2595
# Dessert Parlor         2262
# Takeaway, Delivery     2035
# Casual Dining, Bar     1154
# Bakery                 1141
# Beverage Shop           865
# Bar                     697
# Name: count, dtype: int64

# %%
rest_type_rating = (
    df.groupby("rest_type")["rate"]
    .mean()
    .sort_values(ascending=False)
)

rest_type_rating.head(10)
# Out:
# rest_type
# Pub, Cafe                      4.657500
# Bar, Pub                       4.600000
# Microbrewery                   4.478571
# Pub, Microbrewery              4.452632
# Microbrewery, Bar              4.446154
# Microbrewery, Pub              4.438095
# Casual Dining, Irani Cafee     4.406667
# Cafe, Lounge                   4.400000
# Fine Dining, Lounge            4.400000
# Microbrewery, Casual Dining    4.369421
# Name: rate, dtype: float64

# %%
rest_type_cost = (
    df.groupby("rest_type")["approx_cost(for two people)"]
    .mean()
    .sort_values(ascending=False)
)

rest_type_cost.head(10)
# Out:
# rest_type
# Fine Dining, Bar             3002.500000
# Fine Dining, Lounge          3000.000000
# Fine Dining, Microbrewery    3000.000000
# Fine Dining                  2707.514451
# Bar, Lounge                  2450.000000
# Club, Casual Dining          2400.000000
# Club                         2145.945946
# Lounge, Bar                  2027.777778
# Lounge, Microbrewery         2000.000000
# Bar, Quick Bites             2000.000000
# Name: approx_cost(for two people), dtype: float64

# %%
rest_type_votes = (
    df.groupby("rest_type")["votes"]
    .mean()
    .sort_values(ascending=False)
)

rest_type_votes.head(10)
# Out:
# rest_type
# Microbrewery                   6443.766667
# Microbrewery, Pub              5504.452381
# Lounge, Microbrewery           4653.000000
# Pub, Cafe                      4472.875000
# Pub, Microbrewery              4174.380952
# Casual Dining, Irani Cafee     3686.600000
# Casual Dining, Microbrewery    2527.237288
# Fine Dining, Lounge            2236.785714
# Microbrewery, Lounge           2225.777778
# Cafe, Casual Dining            1952.329480
# Name: votes, dtype: float64

# %% [markdown]
# ## Restaurant Type Insights
#
# - Quick Bites is the most common restaurant type.
# - Pub, Cafe has the highest average rating.
# - Fine Dining, Bar has the highest average cost.
# - Microbrewery receives the highest average customer votes.

# %%
top_cuisines = (
    df["cuisines"]
    .value_counts()
    .head(10)
)

top_cuisines  # Top 10 Most Popular Cuisines
# Out:
# cuisines
# North Indian                           2899
# North Indian, Chinese                  2361
# South Indian                           1828
# Biryani                                 909
# Bakery, Desserts                        907
# Fast Food                               803
# Desserts                                766
# Cafe                                    756
# South Indian, North Indian, Chinese     726
# Bakery                                  649
# Name: count, dtype: int64

# %%
cuisine_rating = (
    df.groupby("cuisines")["rate"]
    .mean()
    .sort_values(ascending=False)
)

cuisine_rating.head(10)
# Out:
# cuisines
# Healthy Food, Salad, Mediterranean                                       4.900000
# Continental, North Indian, Italian, South Indian, Finger Food            4.900000
# Asian, Chinese, Thai, Momos                                              4.900000
# North Indian, European, Mediterranean, BBQ                               4.800000
# Asian, Mediterranean, North Indian, BBQ                                  4.800000
# Continental, North Indian, Chinese, European, BBQ, Finger Food, Asian    4.800000
# European, Mediterranean, North Indian, BBQ                               4.789474
# American, Tex-Mex, Burger, BBQ, Mexican                                  4.750000
# Italian, American, Pizza                                                 4.700000
# Continental, European, BBQ, Chinese, Asian                               4.700000
# Name: rate, dtype: float64

# %%
cuisine_cost = (
    df.groupby("cuisines")["approx_cost(for two people)"]
    .mean()
    .sort_values(ascending=False)
)

cuisine_cost.head(10)
# Out:
# cuisines
# French, Italian                                               6000.0
# North Indian, Continental, Japanese, Chinese, South Indian    4100.0
# Steak, Mediterranean, Grill                                   4000.0
# North Indian, Kashmiri, Mughlai                               3700.0
# Thai, Japanese, Chinese                                       3500.0
# Mangalorean, Konkan, Seafood, Kerala                          3500.0
# North Indian, Italian, Asian, Continental, Mediterranean      3500.0
# North Indian, Italian, Chinese, Japanese                      3400.0
# North Indian, European, Thai                                  3400.0
# Asian, Japanese, Thai                                         3000.0
# Name: approx_cost(for two people), dtype: float64

# %%
cuisine_votes = (
    df.groupby("cuisines")["votes"]
    .mean()
    .sort_values(ascending=False)
)

cuisine_votes.head(10)
# Out:
# cuisines
# Continental, North Indian, Italian, South Indian, Finger Food    16588.500000
# Italian, American, Pizza                                         14956.000000
# North Indian, European, Mediterranean                            10498.846154
# American, Continental, North Indian, Mediterranean                9164.500000
# American, Continental, Salad                                      8379.200000
# American, Continental, North Indian, Salad                        7860.900000
# North Indian, European, Mediterranean, BBQ                        7127.400000
# Cafe, American, Burger                                            7124.875000
# Cafe, American, Burger, Steak                                     7001.372093
# Continental, European, BBQ, Chinese, Asian                        6986.600000
# Name: votes, dtype: float64

# %%
highest_rated = (
    df.sort_values(
        by=["rate", "votes"],
        ascending=[False, False]
    )
)

highest_rated[
    [
        "name",
        "rate",
        "votes",
        "location"
    ]
].head(10)
# Out:
#                               name  rate  votes       location
# 49170  Byg Brewski Brewing Company   4.9  16832  Sarjapur Road
# 49627  Byg Brewski Brewing Company   4.9  16832  Sarjapur Road
# 50059  Byg Brewski Brewing Company   4.9  16832  Sarjapur Road
# 3921   Byg Brewski Brewing Company   4.9  16345  Sarjapur Road
# 4801   Byg Brewski Brewing Company   4.9  16345  Sarjapur Road
# 4944   Byg Brewski Brewing Company   4.9  16345  Sarjapur Road
# 37099    AB's - Absolute Barbecues   4.9   6490            BTM
# 21279    AB's - Absolute Barbecues   4.9   6452            BTM
# 19393    AB's - Absolute Barbecues   4.9   6404            BTM
# 21770    AB's - Absolute Barbecues   4.9   6404            BTM

# %%
high_rating = df.query("rate > 4.5")

high_rating.shape
# Out:
# (588, 18)

# %%
df["rate"].describe()
# Out:
# count    41505.000000
# mean         3.702154
# std          0.439819
# min          1.800000
# 25%          3.400000
# 50%          3.700000
# 75%          4.000000
# max          4.900000
# Name: rate, dtype: float64

# %%
df.groupby("online_order")["rate"].mean()
# Out:
# online_order
# No     3.661147
# Yes    3.723947
# Name: rate, dtype: float64

# %%
most_expensive = (
    df.sort_values(
        by="approx_cost(for two people)",
        ascending=False
    )
)

most_expensive[
    [
        "name",
        "location",
        "approx_cost(for two people)",
        "rate"
    ]
].head(10)
# Out:
#                                          name          location  \
# 45618  Le Cirque Signature - The Leela Palace  Old Airport Road
# 19139  Le Cirque Signature - The Leela Palace  Old Airport Road
# 40266              Royal Afghan - ITC Windsor       Sankey Road
# 41591                  Malties - Radisson Blu      Marathahalli
# 42141                  Malties - Radisson Blu      Marathahalli
# 37715              La Brasserie - Le Meridien       Sankey Road
# 39125              La Brasserie - Le Meridien       Sankey Road
# 39416              La Brasserie - Le Meridien       Sankey Road
# 40262              La Brasserie - Le Meridien       Sankey Road
# 6154                 Riwaz - The Ritz-Carlton    Residency Road
#
#        approx_cost(for two people)  rate
# 45618                       6000.0   4.3
# 19139                       6000.0   4.3
# 40266                       5000.0   4.3
# 41591                       4500.0   4.3
# 42141                       4500.0   4.3
# ...

# %%
cheapest = (
    df.sort_values(
        by="approx_cost(for two people)"
    )
)

cheapest[
    [
        "name",
        "location",
        "approx_cost(for two people)",
        "rate"
    ]
].head(10)
# Out:
#                            name          location  \
# 17773            Srinidhi Sagar  Old Airport Road
# 27091     Srinidhi Sagar Deluxe            Domlur
# 12232  Srinidhi Sagar Food Line       Indiranagar
# 18891  Srinidhi Sagar Food Line       Indiranagar
# 14819  Srinidhi Sagar Food Line       Indiranagar
# 32485            Srinidhi Sagar  Old Airport Road
# 5270   Srinidhi Sagar Food Line       Indiranagar
# 29785     Srinidhi Sagar Deluxe            Domlur
# 37775               Savera Cafe      Shivajinagar
# 14621               Savera Cafe      Shivajinagar
#
#        approx_cost(for two people)  rate
# 17773                         40.0   3.9
# 27091                         40.0   3.6
# 12232                         40.0   3.7
# 18891                         40.0   3.7
# 14819                         40.0   3.7
# 32485                         40.0   3.9
# 5270                          40.0   3.7
# 29785                         40.0   3.6
# ...

# %%
cost_location = (
    df.groupby("location")["approx_cost(for two people)"]
    .mean()
    .sort_values(ascending=False)
)

cost_location.head(10)
# Out:
# location
# Sankey Road         2505.555556
# Race Course Road    1309.352518
# Lavelle Road        1307.934990
# MG Road             1155.704698
# Infantry Road       1062.251656
# Residency Road       966.320475
# St. Marks Road       883.673469
# Langford Town        883.333333
# Cunningham Road      864.969450
# Church Street        834.885764
# Name: approx_cost(for two people), dtype: float64

# %%
cost_rest_type = (
    df.groupby("rest_type")["approx_cost(for two people)"]
    .mean()
    .sort_values(ascending=False)
)

cost_rest_type.head(10)
# Out:
# rest_type
# Fine Dining, Bar             3002.500000
# Fine Dining, Lounge          3000.000000
# Fine Dining, Microbrewery    3000.000000
# Fine Dining                  2707.514451
# Bar, Lounge                  2450.000000
# Club, Casual Dining          2400.000000
# Club                         2145.945946
# Lounge, Bar                  2027.777778
# Lounge, Microbrewery         2000.000000
# Bar, Quick Bites             2000.000000
# Name: approx_cost(for two people), dtype: float64

# %%
(
    df["online_order"]
    .value_counts(normalize=True)
    * 100
).round(2)
# Out:
# online_order
# Yes    58.9
# No     41.1
# Name: proportion, dtype: float64

# %%
df.groupby("online_order")["votes"].mean()
# Out:
# online_order
# No     251.453132
# Yes    308.013394
# Name: votes, dtype: float64

# %%
df.groupby("online_order")["approx_cost(for two people)"].mean()
# Out:
# online_order
# No     600.162163
# Yes    525.714955
# Name: approx_cost(for two people), dtype: float64

# %%
df.groupby("online_order")["rate"].mean()
# Out:
# online_order
# No     3.661147
# Yes    3.723947
# Name: rate, dtype: float64

# %%
df["book_table"].value_counts()
# Out:
# book_table
# No     45017
# Yes     6449
# Name: count, dtype: int64

# %%
df.groupby("book_table")["rate"].mean()
# Out:
# book_table
# No     3.623122
# Yes    4.143464
# Name: rate, dtype: float64

# %%
df.groupby("book_table")["votes"].mean()
# Out:
# book_table
# No      161.224537
# Yes    1147.129788
# Name: votes, dtype: float64

# %%
popular = (
    df.sort_values(
        by="votes",
        ascending=False
    )
)

popular[
    [
        "name",
        "votes",
        "rate",
        "location"
    ]
].head(10)
# Out:
#                               name  votes  rate               location
# 49170  Byg Brewski Brewing Company  16832   4.9          Sarjapur Road
# 49627  Byg Brewski Brewing Company  16832   4.9          Sarjapur Road
# 50059  Byg Brewski Brewing Company  16832   4.9          Sarjapur Road
# 4801   Byg Brewski Brewing Company  16345   4.9          Sarjapur Road
# 3921   Byg Brewski Brewing Company  16345   4.9          Sarjapur Road
# 4944   Byg Brewski Brewing Company  16345   4.9          Sarjapur Road
# 19268                         Toit  14956   4.7            Indiranagar
# 18643                         Toit  14956   4.7            Indiranagar
# 36668                     Truffles  14726   4.7  Koramangala 5th Block
# 36000                     Truffles  14723   4.7  Koramangala 5th Block

# %%
votes_location = (
    df.groupby("location")["votes"]
    .mean()
    .sort_values(ascending=False)
)

votes_location.head(10)
# Out:
# location
# Church Street            1045.657293
# Lavelle Road              956.873346
# Koramangala 5th Block     886.384185
# St. Marks Road            775.798834
# Koramangala 4th Block     673.703048
# Cunningham Road           586.299389
# Koramangala 3rd Block     579.439815
# Indiranagar               575.500963
# MG Road                   470.709150
# Residency Road            432.524444
# Name: votes, dtype: float64

# %%
votes_cuisine = (
    df.groupby("cuisines")["votes"]
    .mean()
    .sort_values(ascending=False)
)

votes_cuisine.head(10)
# Out:
# cuisines
# Continental, North Indian, Italian, South Indian, Finger Food    16588.500000
# Italian, American, Pizza                                         14956.000000
# North Indian, European, Mediterranean                            10498.846154
# American, Continental, North Indian, Mediterranean                9164.500000
# American, Continental, Salad                                      8379.200000
# American, Continental, North Indian, Salad                        7860.900000
# North Indian, European, Mediterranean, BBQ                        7127.400000
# Cafe, American, Burger                                            7124.875000
# Cafe, American, Burger, Steak                                     7001.372093
# Continental, European, BBQ, Chinese, Asian                        6986.600000
# Name: votes, dtype: float64

# %%
high_value = df.query(
    "rate > 4.5 and votes > 1000 and online_order == 'Yes' and `approx_cost(for two people)` < 1000"
)

high_value[
    [
        "name",
        "location",
        "rate",
        "votes",
        "approx_cost(for two people)"
    ]
].head(20)
# Out:
#                          name               location  rate  votes  \
# 7                      Onesta           Banashankari   4.6   2556
# 44                     Onesta           Banashankari   4.6   2556
# 557                    Onesta           Banashankari   4.6   2556
# 2497                   Onesta           Basavanagudi   4.6   1755
# 2584                   Onesta           Banashankari   4.6   2556
# 3293                   Onesta           Basavanagudi   4.6   1755
# 5153   Belgian Waffle Factory           Brigade Road   4.9   1746
# 5809   Belgian Waffle Factory           Brigade Road   4.9   1746
# 6995                   Onesta           Marathahalli   4.6   2750
# 8341          Lot Like Crepes  Koramangala 7th Block   4.7   1022
# 9158          Lot Like Crepes  Koramangala 7th Block   4.7   1022
# 10269         Lot Like Crepes  Koramangala 7th Block   4.6   1028
# 10938         Lot Like Crepes  Koramangala 7th Block   4.7   1022
# ...

# %%
import matplotlib.pyplot as plt

top_locations = df["location"].value_counts().head(10)

plt.figure(figsize=(10,5))
plt.bar(top_locations.index, top_locations.values)
plt.xticks(rotation=45)
plt.title("Top 10 Restaurant Locations")
plt.xlabel("Location")
plt.ylabel("Number of Restaurants")
plt.show()

# %%
top_rest = df["rest_type"].value_counts().head(10)

plt.figure(figsize=(10,5))
plt.bar(top_rest.index, top_rest.values)
plt.xticks(rotation=45)
plt.title("Top 10 Restaurant Types")
plt.show()

# %%
top_cuisine = df["cuisines"].value_counts().head(10)

plt.figure(figsize=(10,5))
plt.bar(top_cuisine.index, top_cuisine.values)
plt.xticks(rotation=90)
plt.title("Top 10 Cuisines")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["rate"].dropna(), bins=20)
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["approx_cost(for two people)"], bins=20)
plt.title("Cost Distribution")
plt.xlabel("Cost")
plt.ylabel("Count")
plt.show()

# %%
df["online_order"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.ylabel("")
plt.title("Online Order")
plt.show()

# %%
df["book_table"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.ylabel("")
plt.title("Table Booking")
plt.show()

# %%
top = df.sort_values("votes",ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.barh(top["name"], top["votes"])
plt.title("Most Popular Restaurants")
plt.show()

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

plt.figure(figsize=(6,4))
sns.heatmap(
    df[["rate","votes","approx_cost(for two people)"]].corr(),
    annot=True,
    cmap="coolwarm"
)
plt.title("Correlation Heatmap")
plt.show()
